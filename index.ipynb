# %%
import pandas as pd
tabla = pd.read_csv("ventas.csv", delimiter=";")
type(tabla.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
tabla.index[22]
# Out:
# 22

# %%
tabla.head()
# Out:
#       Fecha          Vendedor Región           Artículo    Categoría  \
# 0  1/1/2016      Steve Ashton  Norte   Medias Femeninas   Vestimenta
# 1  1/1/2016  Trevor Snodgrass  Oeste          Chocolate  Comestibles
# 2  1/1/2016        Sarah Bond    Sur             Gorras   Vestimenta
# 3  1/1/2016   Desmond Delaney    Sur  Sánguche de Queso  Comestibles
# 4  1/1/2016   Desmond Delaney   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
# tabla.index[22]=1  Esto no se puede
tabla.set_index("Vendedor")
# Out:
#                       Fecha Región           Artículo    Categoría  Unidades  \
# Vendedor
# Steve Ashton       1/1/2016  Norte   Medias Femeninas   Vestimenta         6
# Trevor Snodgrass   1/1/2016  Oeste          Chocolate  Comestibles         8
# Sarah Bond         1/1/2016    Sur             Gorras   Vestimenta         3
# Desmond Delaney    1/1/2016    Sur  Sánguche de Queso  Comestibles         9
# Desmond Delaney    1/1/2016   Este          Chocolate  Comestibles        14
# ...                     ...    ...                ...          ...       ...
# Sarah Bond        31/1/2016    Sur            Bufanda   Vestimenta         6
# Dustin Gee        31/1/2016   Este          Sandalias   Vestimenta        11
# Dustin Gee        31/1/2016   Este  Sánguche de Queso  Comestibles         4
# Dustin Gee        31/1/2016  Norte         Escobillón        Hogar         8
# Trevor Snodgrass  31/1/2016    Sur          Pepinillo  Comestibles         7
#
#                  Ganancia
# ...

# %% [markdown]
# # set Index

# %%
tabla.set_index("Vendedor", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7668/776451127.py in ?()
# ----> 1 tabla.set_index("Vendedor", inplace=True)
#
# ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Vendedor'] are in the columns"

# %%
tabla.head()
# Out:
#                      Fecha Región           Artículo    Categoría  Unidades  \
# Vendedor
# Steve Ashton      1/1/2016  Norte   Medias Femeninas   Vestimenta         6
# Trevor Snodgrass  1/1/2016  Oeste          Chocolate  Comestibles         8
# Sarah Bond        1/1/2016    Sur             Gorras   Vestimenta         3
# Desmond Delaney   1/1/2016    Sur  Sánguche de Queso  Comestibles         9
# Desmond Delaney   1/1/2016   Este          Chocolate  Comestibles        14
#
#                  Ganancia
# Vendedor
# Steve Ashton        18,00
# Trevor Snodgrass     3,84
# Sarah Bond           6,30
# Desmond Delaney     14,40
# Desmond Delaney      6,72

# %%
tabla.reset_index(inplace=True)

# %%
ven = tabla.set_index("Vendedor")

# %%
ven.head()
# Out:
#                   index     Fecha Región           Artículo    Categoría  \
# Vendedor
# Steve Ashton          0  1/1/2016  Norte   Medias Femeninas   Vestimenta
# Trevor Snodgrass      1  1/1/2016  Oeste          Chocolate  Comestibles
# Sarah Bond            2  1/1/2016    Sur             Gorras   Vestimenta
# Desmond Delaney       3  1/1/2016    Sur  Sánguche de Queso  Comestibles
# Desmond Delaney       4  1/1/2016   Este          Chocolate  Comestibles
#
#                   Unidades Ganancia
# Vendedor
# Steve Ashton             6    18,00
# Trevor Snodgrass         8     3,84
# Sarah Bond               3     6,30
# Desmond Delaney          9    14,40
# Desmond Delaney         14     6,72

# %%
ven.reset_index(inplace=True)

# %%
ven.head()
# Out:
#            Vendedor  index     Fecha Región           Artículo    Categoría  \
# 0      Steve Ashton      0  1/1/2016  Norte   Medias Femeninas   Vestimenta
# 1  Trevor Snodgrass      1  1/1/2016  Oeste          Chocolate  Comestibles
# 2        Sarah Bond      2  1/1/2016    Sur             Gorras   Vestimenta
# 3   Desmond Delaney      3  1/1/2016    Sur  Sánguche de Queso  Comestibles
# 4   Desmond Delaney      4  1/1/2016   Este          Chocolate  Comestibles
#
#    Unidades Ganancia
# 0         6    18,00
# 1         8     3,84
# 2         3     6,30
# 3         9    14,40
# 4        14     6,72

# %%
ven.sort_index(inplace=True, ascending=False)
ven.head()
# Out:
#              Vendedor  index      Fecha Región           Artículo  \
# 459  Trevor Snodgrass    459  31/1/2016    Sur          Pepinillo
# 458        Dustin Gee    458  31/1/2016  Norte         Escobillón
# 457        Dustin Gee    457  31/1/2016   Este  Sánguche de Queso
# 456        Dustin Gee    456  31/1/2016   Este          Sandalias
# 455        Sarah Bond    455  31/1/2016    Sur            Bufanda
#
#        Categoría  Unidades Ganancia
# 459  Comestibles         7     2,10
# 458        Hogar         8     6,80
# 457  Comestibles         4     6,40
# 456   Vestimenta        11   115,50
# 455   Vestimenta         6    16,50
